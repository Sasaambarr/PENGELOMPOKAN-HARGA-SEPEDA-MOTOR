# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasetmotor.csv')

# %%
df
# Out:
#       ID           Merek  Harga (Juta)  Kapasitas Mesin (cc) Transmisi  \
# 0      1      Honda NMAX            43                   281    Manual
# 1      2     Yamaha Beat            17                   116  Otomatis
# 2      3  Kawasaki Vario            24                   149  Otomatis
# 3      4      Suzuki CBR            42                   280    Manual
# 4      5    Suzuki Vario            29                   156  Otomatis
# ..   ...             ...           ...                   ...       ...
# 145  146    Yamaha Aerox            21                   152  Otomatis
# 146  147     Honda Aerox            29                   127    Manual
# 147  148   Honda Supra X            18                   102    Manual
# 148  149    Yamaha Ninja            37                   232    Manual
# 149  150    Kawasaki Mio            16                   124  Otomatis
#
#      Konsumsi BBM (km/l)  Berat (kg)
# 0                     31         159
# 1                     64          96
# ...

# %% [markdown]
# mencari nilai kosong

# %%
df.isnull().sum()
# Out:
# ID                      0
# Merek                   0
# Harga (Juta)            0
# Kapasitas Mesin (cc)    0
# Transmisi               0
# Konsumsi BBM (km/l)     0
# Berat (kg)              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    150 non-null    int64
#  1   Merek                 150 non-null    object
#  2   Harga (Juta)          150 non-null    int64
#  3   Kapasitas Mesin (cc)  150 non-null    int64
#  4   Transmisi             150 non-null    object
#  5   Konsumsi BBM (km/l)   150 non-null    int64
#  6   Berat (kg)            150 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 8.3+ KB

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
# memvisualisasikan outlier menggunakan boxplot untuk kolom-kolom 
plt.figure(figsize=(30,30))
df.boxplot()
plt.show()

# %%
df.to_csv('datasetmotorbersih.csv', index=False)
